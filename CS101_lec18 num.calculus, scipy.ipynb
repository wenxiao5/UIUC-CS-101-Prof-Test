# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Numerical Integration

# %%
import numpy as np
import scipy.integrate as spi
def y( x ):
    return 1/(np.sqrt(x)+x**(1/3))
integral = spi.quad( y,0,1 )
integral
# Out:
# (0.8411169166213133, 4.252410867877643e-09)

# %%
import numpy as np
import scipy.integrate as spi
x = np.linspace( 0,1,11 )
y = 1 - x ** 2
integral = spi.simps( y,x )
integral
# Out:
# 0.6666666666666666

# %%
def crack_pin(pin):
    for a in range(10):
        for b in range(10):
            for c in range(10):
                for d in range(10):
                    p=str(a)+str(b)+str(c)+str(d)
                    if check_pin:
                        return p

# %%
crack_pin('1234')
# Out:
# '1234'

# %% [markdown]
# ### example

# %%
import numpy as np
import scipy.integrate as spi

def v( t ):
    return -9.8 * t

t = np.linspace( 0,1,11 )
x = []
for time in t:
    x.append( spi.quad( v,0.0,time ) )

import matplotlib.pyplot as plt
plt.plot( t,x )
plt.show()

# %%
x
# Out:
# [(-0.0, 0.0),
#  (-0.049000000000000016, 5.440092820663268e-16),
#  (-0.19600000000000006, 2.1760371282653074e-15),
#  (-0.4410000000000001, 4.896083538596941e-15),
#  (-0.7840000000000003, 8.70414851306123e-15),
#  (-1.225, 1.3600232051658169e-14),
#  (-1.7640000000000005, 1.9584334154387765e-14),
#  (-2.4010000000000007, 2.6656454821250017e-14),
#  (-3.136000000000001, 3.481659405224492e-14),
#  (-3.9690000000000003, 4.406475184737247e-14),
#  (-4.9, 5.4400928206632677e-14)]
